# %%
print("hello")
# Out:
# hello

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\jacqu\IdeaProjects\python_learn\venv\Scripts\python.exe

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3], [1,4,5])
